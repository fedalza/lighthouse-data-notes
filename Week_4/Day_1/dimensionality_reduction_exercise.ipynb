# %% [markdown]
# ## Feature selection
#
# Create own functions to filter features based on the following criteria:
#
# * lower variance than x
# * number of missing values is more than *x* %
# * one of each pair of features, which are correlated together more than *x*

# %% [markdown]
# Use two data sources as input:
# - output dataset from the feature engineering exercise last week.
# - output dataset from the PCA exercise
#
# Apply your functions to the combination of these two datasource and come up with the final dataset that can be used for training.
#
# > #### Note
# > Don't forget to keep target variable (duration_seconds) intact

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import VarianceThreshold

# %%
#X = pd.read_csv('pca_data.csv', index_col=0)
# X.head()

# %%
X = pd.read_csv('feature_eng_data.csv', index_col=0)
Y = pd.DataFrame(X['duration_seconds'],index=X.index)
X.drop(columns=['duration_seconds'],inplace=True)
X.head()
# Out:
#          lat         lng  apparentTemperature  cloudCover  cloudCoverError  \
# 0  29.883056  -97.941111                25.86        0.00              NaN
# 1  29.384210  -98.581082                26.12        0.00              NaN
# 2  53.200000   -2.916667                15.56        0.75              NaN
# 3  28.978333  -96.645833                22.68        0.12              NaN
# 4  21.418056 -157.803611                25.74        0.63              NaN
#
#    dewPoint  dewPointError  humidity  humidityError  precipIntensity  ...  \
# 0     20.56            NaN      0.73            NaN              0.0  ...
# 1     21.72            NaN      0.77            NaN              0.0  ...
# 2     12.86            NaN      0.84            NaN              NaN  ...
# 3     17.04            NaN      0.71            NaN              NaN  ...
# 4     21.47            NaN      0.77            NaN              NaN  ...
#
#    windBearing  windBearingError  windSpeed  windSpeedError  \
# 0        154.0               NaN       4.89             NaN
# 1        135.0               NaN       6.60             NaN
# 2          NaN               NaN        NaN             NaN
# 3        136.0               NaN       2.75             NaN
# 4         80.0               NaN       3.60             NaN
#
#    ast_absolute_magnitude_h  ast_estimated_diameter  ast_miss_distance  \
# 0                      21.5                0.297879         42621696.0
# 1                      21.5                0.297879         42621696.0
# 2                      21.5                0.297879         42621696.0
# 3                      21.5                0.297879         42621696.0
# 4                      21.5                0.297879         42621696.0
#
#    ast_relative_velocity  days_to_report  period_of_day
# 0           13778.372043           19923            3.0
# 1           13778.372043           20521            3.0
# 2           13778.372043           19096            2.0
# 3           13778.372043           17265            3.0
# 4           13778.372043           15809            3.0
#
# [5 rows x 28 columns]

# %%
def var_filter(df,threshold=0.10):
    vt = VarianceThreshold(threshold)
    df_transformed = vt.fit_transform(df)
    # columns we have selected
    # get_support() is method of VarianceThreshold and stores boolean of each variable in the numpy array.
    selected_columns = df.columns[vt.get_support()]
    # transforming an array back to a data-frame preserves column labels
    return pd.DataFrame(df_transformed, columns = selected_columns)

# %%
def miss_val_filter(df,threshold=0.30):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    todrop = missing_data[missing_data['Percent']>threshold].index.tolist()
    return df.drop(columns=todrop)

# %%
def corr_feat_filter(df,threshold=0.8):
    # Removing correlated features
    # step 1 - calculate a correlation matrix
    df_corr = df.corr().abs()
    
    # step 2 - get pairs of highly correlated features
    indices = np.where(df_corr > 0.8) 
    indices = [(df_corr.index[x], df_corr.columns[y]) for x, y in zip(*indices) if x != y and x < y]

    # step 3 - remove correlated columns
    for idx in indices: #each pair
        try:
            df.drop(idx[1], axis = 1, inplace=True)
        except KeyError:
            pass
    return df

# %%
X = var_filter(X)
X.head()
# Out:
#          lat         lng  apparentTemperature  cloudCover  dewPoint  \
# 0  29.883056  -97.941111                25.86        0.00     20.56
# 1  29.384210  -98.581082                26.12        0.00     21.72
# 2  53.200000   -2.916667                15.56        0.75     12.86
# 3  28.978333  -96.645833                22.68        0.12     17.04
# 4  21.418056 -157.803611                25.74        0.63     21.47
#
#    dewPointError  precipIntensity  pressure  pressureError  temperature  ...  \
# 0            NaN              0.0   1009.05            NaN        25.86  ...
# 1            NaN              0.0   1008.81            NaN        26.12  ...
# 2            NaN              NaN   1019.00            NaN        15.56  ...
# 3            NaN              NaN   1020.64            NaN        22.68  ...
# 4            NaN              NaN   1015.33            NaN        25.74  ...
#
#    windBearing  windBearingError  windSpeed  windSpeedError  \
# 0        154.0               NaN       4.89             NaN
# 1        135.0               NaN       6.60             NaN
# 2          NaN               NaN        NaN             NaN
# 3        136.0               NaN       2.75             NaN
# 4         80.0               NaN       3.60             NaN
#
#    ast_absolute_magnitude_h  ast_estimated_diameter  ast_miss_distance  \
# 0                      21.5                0.297879         42621696.0
# 1                      21.5                0.297879         42621696.0
# 2                      21.5                0.297879         42621696.0
# 3                      21.5                0.297879         42621696.0
# 4                      21.5                0.297879         42621696.0
#
#    ast_relative_velocity  days_to_report  period_of_day
# 0           13778.372043         19923.0            3.0
# 1           13778.372043         20521.0            3.0
# 2           13778.372043         19096.0            2.0
# 3           13778.372043         17265.0            3.0
# 4           13778.372043         15809.0            3.0
#
# [5 rows x 24 columns]

# %%
X = miss_val_filter(X)
X.head()
# Out:
#          lat         lng  apparentTemperature  cloudCover  dewPoint  pressure  \
# 0  29.883056  -97.941111                25.86        0.00     20.56   1009.05
# 1  29.384210  -98.581082                26.12        0.00     21.72   1008.81
# 2  53.200000   -2.916667                15.56        0.75     12.86   1019.00
# 3  28.978333  -96.645833                22.68        0.12     17.04   1020.64
# 4  21.418056 -157.803611                25.74        0.63     21.47   1015.33
#
#    temperature         time  visibility  windBearing  windSpeed  \
# 0        25.86 -638227800.0       16.09        154.0       4.89
# 1        26.12 -638226000.0       16.09        135.0       6.60
# 2        15.56 -448959600.0        2.90          NaN        NaN
# 3        22.68 -417304800.0       16.09        136.0       2.75
# 4        25.74 -291060000.0       16.09         80.0       3.60
#
#    ast_absolute_magnitude_h  ast_estimated_diameter  ast_miss_distance  \
# 0                      21.5                0.297879         42621696.0
# 1                      21.5                0.297879         42621696.0
# 2                      21.5                0.297879         42621696.0
# 3                      21.5                0.297879         42621696.0
# 4                      21.5                0.297879         42621696.0
#
#    ast_relative_velocity  days_to_report  period_of_day
# 0           13778.372043         19923.0            3.0
# 1           13778.372043         20521.0            3.0
# 2           13778.372043         19096.0            2.0
# 3           13778.372043         17265.0            3.0
# 4           13778.372043         15809.0            3.0

# %%
X = corr_feat_filter(X)
X.head()
# Out:
#          lat         lng  apparentTemperature  cloudCover  pressure  \
# 0  29.883056  -97.941111                25.86        0.00   1009.05
# 1  29.384210  -98.581082                26.12        0.00   1008.81
# 2  53.200000   -2.916667                15.56        0.75   1019.00
# 3  28.978333  -96.645833                22.68        0.12   1020.64
# 4  21.418056 -157.803611                25.74        0.63   1015.33
#
#           time  visibility  windBearing  windSpeed  ast_absolute_magnitude_h  \
# 0 -638227800.0       16.09        154.0       4.89                      21.5
# 1 -638226000.0       16.09        135.0       6.60                      21.5
# 2 -448959600.0        2.90          NaN        NaN                      21.5
# 3 -417304800.0       16.09        136.0       2.75                      21.5
# 4 -291060000.0       16.09         80.0       3.60                      21.5
#
#    ast_miss_distance  ast_relative_velocity  period_of_day
# 0         42621696.0           13778.372043            3.0
# 1         42621696.0           13778.372043            3.0
# 2         42621696.0           13778.372043            2.0
# 3         42621696.0           13778.372043            3.0
# 4         42621696.0           13778.372043            3.0
