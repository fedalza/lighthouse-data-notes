# %%
# import geopandas and matplotlib
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# countries data
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# * print top 5 rows of world data-frame

# %%
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %% [markdown]
# * remove continents which have only one country in data-frame

# %%
# continents with only one country
cont1 = world.groupby('continent').filter(lambda x: len(x) == 1)
cont1


# remove these continents
world = world.drop(index=cont1.index)

# %% [markdown]
# * create dataframe with top 3 most populated countries from each continent
# * store the result in data-frame with name 'world_filtered'

# %%
world_filtered = world.groupby(['continent']).apply(lambda x: x.nlargest(3,['pop_est'])).reset_index(drop=True)

# %% [markdown]
# * print 'world_filtered' data-frame

# %%
world_filtered
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0    190632261         Africa                   Nigeria    NGA   1089000.0
# 1    105350020         Africa                  Ethiopia    ETH    174700.0
# 2     97041072         Africa                     Egypt    EGY   1105000.0
# 3   1379302771           Asia                     China    CHN  21140000.0
# 4   1281935911           Asia                     India    IND   8721000.0
# 5    260580739           Asia                 Indonesia    IDN   3028000.0
# 6    142257519         Europe                    Russia    RUS   3745000.0
# 7     80594017         Europe                   Germany    DEU   3979000.0
# 8     67106161         Europe                    France    -99   2699000.0
# 9    326625791  North America  United States of America    USA  18560000.0
# 10   124574795  North America                    Mexico    MEX   2307000.0
# 11    35623680  North America                    Canada    CAN   1674000.0
# 12    23232413        Oceania                 Australia    AUS   1189000.0
# 13     6909701        Oceania          Papua New Guinea    PNG     28020.0
# 14     4510327        Oceania               New Zealand    NZL    174800.0
# 15   207353391  South America                    Brazil    BRA   3081000.0
# 16    47698524  South America                  Colombia    COL    688000.0
# 17    44293293  South America                 Argentina    ARG    879400.0
#
#                                              geometry
# 0   POLYGON ((2.692 6.259, 2.749 7.871, 2.724 8.50...
# 1   POLYGON ((47.789 8.003, 44.964 5.002, 43.661 4...
# 2   POLYGON ((36.866 22.000, 32.900 22.000, 29.020...
# 3   MULTIPOLYGON (((109.475 18.198, 108.655 18.508...
# 4   POLYGON ((97.327 28.262, 97.403 27.883, 97.052...
# 5   MULTIPOLYGON (((141.000 -2.600, 141.017 -5.859...
# 6   MULTIPOLYGON (((178.725 71.099, 180.000 71.516...
# 7   POLYGON ((14.120 53.757, 14.353 53.248, 14.075...
# 8   MULTIPOLYGON (((-51.658 4.156, -52.249 3.241, ...
# 9   MULTIPOLYGON (((-122.840 49.000, -120.000 49.0...
# 10  POLYGON ((-117.128 32.535, -115.991 32.612, -1...
# 11  MULTIPOLYGON (((-122.840 49.000, -122.974 49.0...
# 12  MULTIPOLYGON (((147.689 -40.808, 148.289 -40.8...
# 13  MULTIPOLYGON (((141.000 -2.600, 142.735 -3.289...
# 14  MULTIPOLYGON (((176.886 -40.066, 176.508 -40.6...
# 15  POLYGON ((-53.374 -33.768, -53.651 -33.202, -5...
# 16  POLYGON ((-66.876 1.253, -67.065 1.130, -67.26...
# 17  MULTIPOLYGON (((-68.634 -52.636, -68.250 -53.1...

# %% [markdown]
# * create choropleth map of world
# * the colors of countries from 'world_filtered' are based on population
# * other countries are white with black edgecolor

# %%
# create figure and axes
fig, ax = plt.subplots(figsize=(15,12))

# create map from world_filtered data-frame
world_filtered.plot(column='pop_est', ax=ax, legend=True,
           legend_kwds={'label': "Population by Country",
                        'orientation': "horizontal"})
# add the rest of the countries
world.plot(column='pop_est', ax=ax, legend=True,
           legend_kwds={'label': "Population by Country",
                        'orientation': "horizontal"})

plt.show()

# %% [markdown]
# * add New York, Berlin, Paris, Toronto, Calgary, Tokyo to the map you have created before
# * to get geometry of these cities use gpd.tools.geocode(['New York', 'Berlin', 'Paris','Toronto', 'Calgary', 'Tokyo'])
# * if you do not have geopy library instaled, install it with the following command in the jupyter notebook cell
# * !pip install geopy

# %%
# get geometry
cities = gpd.tools.geocode(['New York', 'Berlin', 'Paris','Toronto', 'Calgary', 'Tokyo'])

# create figure and axes
fig, ax = plt.subplots(figsize=(15,12))

# create map from world_filtered data-frame
world_filtered.plot(column='pop_est', ax=ax, legend=True,
           legend_kwds={'label': "Population by Country",
                        'orientation': "horizontal"})


# add the rest of the countries
world.plot(column='pop_est', ax=ax, legend=True,
           legend_kwds={'label': "Population by Country",
                        'orientation': "horizontal"})


# add cities
cities.plot(ax=ax ,marker='*', color='white', markersize=5)
plt.show()
