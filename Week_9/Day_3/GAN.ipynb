# %%
# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt

# %%
# Generation resolution - Must be square 
# Training data is also scaled to this.
# Note GENERATE_RES 4 or higher  
# will blow Google CoLab's memory and have not
# been tested extensivly.
GENERATE_RES = 3 # Generation resolution factor 
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

# Size vector to generate images from
SEED_SIZE = 100

# Configuration
DATA_PATH = './images'
EPOCHS = 500
BATCH_SIZE = 32
BUFFER_SIZE = 60000

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 96px square images.

# %%
# Image set has 11,682 images.  Can take over an hour 
# for initial preprocessing.
# Because of this time needed, save a Numpy preprocessed file.
# Note, that file is large enough to cause problems for 
# sume verisons of Pickle,
# so Numpy binary files are used.
training_binary_path = os.path.join(DATA_PATH,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
    start = time.time()
    print("Loading training images...")

    training_data = []
    #faces_path = os.path.join(DATA_PATH,'face_images')
    faces_path = DATA_PATH
    for filename in tqdm(os.listdir(faces_path)):
        path = os.path.join(faces_path,filename)
    image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
    training_data.append(np.asarray(image))
    training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
    training_data = training_data.astype(np.float32)
    training_data = training_data / 127.5 - 1.


    print("Saving training image binary...")
    np.save(training_binary_path,training_data)
    elapsed = time.time()-start
    print(f'Image preprocess time: {hms_string(elapsed)}')
else:
    print("Loading previous training pickle...")
    training_data = np.load(training_binary_path)
# Out:
# Looking for file: ./images/training_data_96_96.npy
# Loading previous training pickle...

# %%
# Batch and shuffle the data
train_dataset = tf.data.Dataset.from_tensor_slices(training_data) \
    .shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    model.add(UpSampling2D())
    model.add(Conv2D(128,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    if GENERATE_RES>1:
        model.add(UpSampling2D(size=(GENERATE_RES,GENERATE_RES)))
        model.add(Conv2D(128,kernel_size=3,padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    return model


def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
def save_images(cnt,noise):
    image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)
  
    generated_images = generator.predict(noise)

    generated_images = 0.5 * generated_images + 0.5

    image_count = 0
    for row in range(PREVIEW_ROWS):
        for col in range(PREVIEW_COLS):
            r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
            c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
            image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] \
            = generated_images[image_count] * 255
            image_count += 1

          
    output_path = os.path.join(DATA_PATH,'output')
    if not os.path.exists(output_path):
        os.makedirs(output_path)
  
    filename = os.path.join(output_path,f"train-{cnt}.png")
    im = Image.fromarray(image_array)
    im.save(filename)

# %%
generator = build_generator(SEED_SIZE, IMAGE_CHANNELS)

noise = tf.random.normal([1, SEED_SIZE])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print(decision)
# Out:
# tf.Tensor([[0.5002515]], shape=(1, 1), dtype=float32)

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images):
    seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(seed, training=True)

        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)
    

        gradients_of_generator = gen_tape.gradient(\
        gen_loss, generator.trainable_variables)
        gradients_of_discriminator = disc_tape.gradient(\
        disc_loss, discriminator.trainable_variables)

        generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
        discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
    return gen_loss,disc_loss

# %%
def train(dataset, epochs):
    fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
    start = time.time()

    for epoch in range(epochs):
        epoch_start = time.time()

        gen_loss_list = []
        disc_loss_list = []

        for image_batch in dataset:
            t = train_step(image_batch)
            gen_loss_list.append(t[0])
            disc_loss_list.append(t[1])

        g_loss = sum(gen_loss_list) / len(gen_loss_list)
        d_loss = sum(disc_loss_list) / len(disc_loss_list)

        epoch_elapsed = time.time()-epoch_start
        print(f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss},'\
           ' {hms_string(epoch_elapsed)}')
        save_images(epoch,fixed_seed)

    elapsed = time.time()-start
    print(f'Training time: {hms_string(elapsed)}')

# %%
EPOCHS
# Out:
# 50

# %%
train(train_dataset, EPOCHS)
# Out:
# Epoch 1, gen loss=0.6920791864395142,disc loss=1.0088657140731812, {hms_string(epoch_elapsed)}
# Epoch 2, gen loss=0.6920531988143921,disc loss=1.007670283317566, {hms_string(epoch_elapsed)}
# Epoch 3, gen loss=0.6921625137329102,disc loss=1.0079619884490967, {hms_string(epoch_elapsed)}
# Epoch 4, gen loss=0.6925221681594849,disc loss=1.0073964595794678, {hms_string(epoch_elapsed)}
# Epoch 5, gen loss=0.6923396587371826,disc loss=1.0088739395141602, {hms_string(epoch_elapsed)}
# Epoch 6, gen loss=0.6924972534179688,disc loss=1.0074448585510254, {hms_string(epoch_elapsed)}
# Epoch 7, gen loss=0.6922366619110107,disc loss=1.0075037479400635, {hms_string(epoch_elapsed)}
# Epoch 8, gen loss=0.6922798156738281,disc loss=1.0097551345825195, {hms_string(epoch_elapsed)}
# Epoch 9, gen loss=0.6904584169387817,disc loss=1.009194254875183, {hms_string(epoch_elapsed)}
# Epoch 10, gen loss=0.6925473213195801,disc loss=1.0072449445724487, {hms_string(epoch_elapsed)}
# Epoch 11, gen loss=0.6921247243881226,disc loss=1.0082964897155762, {hms_string(epoch_elapsed)}
# Epoch 12, gen loss=0.692307710647583,disc loss=1.0086785554885864, {hms_string(epoch_elapsed)}
# Epoch 13, gen loss=0.691154956817627,disc loss=1.0087324380874634, {hms_string(epoch_elapsed)}
# Epoch 14, gen loss=0.6920286417007446,disc loss=1.007981777191162, {hms_string(epoch_elapsed)}
# Epoch 15, gen loss=0.6925361156463623,disc loss=1.007364273071289, {hms_string(epoch_elapsed)}
# Epoch 16, gen loss=0.6927331686019897,disc loss=1.0076342821121216, {hms_string(epoch_elapsed)}
# Epoch 17, gen loss=0.6927906274795532,disc loss=1.0074093341827393, {hms_string(epoch_elapsed)}
# Epoch 18, gen loss=0.6925715208053589,disc loss=1.0070326328277588, {hms_string(epoch_elapsed)}
# Epoch 19, gen loss=0.6924334168434143,disc loss=1.0076284408569336, {hms_string(epoch_elapsed)}
# Epoch 20, gen loss=0.6921011209487915,disc loss=1.007939338684082, {hms_string(epoch_elapsed)}
# Epoch 21, gen loss=0.6925680041313171,disc loss=1.0090869665145874, {hms_string(epoch_elapsed)}
# Epoch 22, gen loss=0.6922847032546997,disc loss=1.0075024366378784, {hms_string(epoch_elapsed)}
# Epoch 23, gen loss=0.6925607919692993,disc loss=1.0074213743209839, {hms_string(epoch_elapsed)}
# Epoch 24, gen loss=0.6927450299263,disc loss=1.006967306137085, {hms_string(epoch_elapsed)}
# Epoch 25, gen loss=0.6926548480987549,disc loss=1.0071914196014404, {hms_string(epoch_elapsed)}
# Epoch 26, gen loss=0.6923092603683472,disc loss=1.0078773498535156, {hms_string(epoch_elapsed)}
# Epoch 27, gen loss=0.6925051212310791,disc loss=1.0073919296264648, {hms_string(epoch_elapsed)}
# Epoch 28, gen loss=0.6925631761550903,disc loss=1.007447361946106, {hms_string(epoch_elapsed)}
# Epoch 29, gen loss=0.6923678517341614,disc loss=1.0084121227264404, {hms_string(epoch_elapsed)}
# Epoch 30, gen loss=0.6927391886711121,disc loss=1.0077954530715942, {hms_string(epoch_elapsed)}
# Epoch 31, gen loss=0.692197322845459,disc loss=1.007416009902954, {hms_string(epoch_elapsed)}
# Epoch 32, gen loss=0.6924120783805847,disc loss=1.0075739622116089, {hms_string(epoch_elapsed)}
# Epoch 33, gen loss=0.6927691698074341,disc loss=1.0068528652191162, {hms_string(epoch_elapsed)}
# Epoch 34, gen loss=0.6909570693969727,disc loss=1.0099022388458252, {hms_string(epoch_elapsed)}
# Epoch 35, gen loss=0.69268798828125,disc loss=1.0073320865631104, {hms_string(epoch_elapsed)}
# Epoch 36, gen loss=0.6921572089195251,disc loss=1.0085421800613403, {hms_string(epoch_elapsed)}
# Epoch 37, gen loss=0.6927770376205444,disc loss=1.0070286989212036, {hms_string(epoch_elapsed)}
# Epoch 38, gen loss=0.6926488876342773,disc loss=1.0084900856018066, {hms_string(epoch_elapsed)}
# Epoch 39, gen loss=0.6927448511123657,disc loss=1.0068495273590088, {hms_string(epoch_elapsed)}
# Epoch 40, gen loss=0.6922715902328491,disc loss=1.009174108505249, {hms_string(epoch_elapsed)}
# Epoch 41, gen loss=0.6925992369651794,disc loss=1.0070246458053589, {hms_string(epoch_elapsed)}
# Epoch 42, gen loss=0.6925128698348999,disc loss=1.0070775747299194, {hms_string(epoch_elapsed)}
# Epoch 43, gen loss=0.6921865940093994,disc loss=1.0073994398117065, {hms_string(epoch_elapsed)}
# Epoch 44, gen loss=0.6923099160194397,disc loss=1.0078728199005127, {hms_string(epoch_elapsed)}
# Epoch 45, gen loss=0.6928111910820007,disc loss=1.0067747831344604, {hms_string(epoch_elapsed)}
# Epoch 46, gen loss=0.692726731300354,disc loss=1.0072247982025146, {hms_string(epoch_elapsed)}
# Epoch 47, gen loss=0.6925035715103149,disc loss=1.0072907209396362, {hms_string(epoch_elapsed)}
# Epoch 48, gen loss=0.6926906704902649,disc loss=1.0068881511688232, {hms_string(epoch_elapsed)}
# Epoch 49, gen loss=0.6926575899124146,disc loss=1.0073692798614502, {hms_string(epoch_elapsed)}
# Epoch 50, gen loss=0.6928269863128662,disc loss=1.0069090127944946, {hms_string(epoch_elapsed)}
# Epoch 51, gen loss=0.6927483677864075,disc loss=1.0069327354431152, {hms_string(epoch_elapsed)}
# Epoch 52, gen loss=0.69236159324646,disc loss=1.0079753398895264, {hms_string(epoch_elapsed)}
# Epoch 53, gen loss=0.6925230026245117,disc loss=1.0070923566818237, {hms_string(epoch_elapsed)}
# Epoch 54, gen loss=0.6924997568130493,disc loss=1.007408857345581, {hms_string(epoch_elapsed)}
# Epoch 55, gen loss=0.6922193765640259,disc loss=1.0075095891952515, {hms_string(epoch_elapsed)}
# Epoch 56, gen loss=0.6926186084747314,disc loss=1.0071049928665161, {hms_string(epoch_elapsed)}
# Epoch 57, gen loss=0.6927803754806519,disc loss=1.006964921951294, {hms_string(epoch_elapsed)}
# Epoch 58, gen loss=0.6927978992462158,disc loss=1.0074254274368286, {hms_string(epoch_elapsed)}
# Epoch 59, gen loss=0.6916718482971191,disc loss=1.0084480047225952, {hms_string(epoch_elapsed)}
# Epoch 60, gen loss=0.6927924156188965,disc loss=1.0069692134857178, {hms_string(epoch_elapsed)}
# Epoch 61, gen loss=0.6929612755775452,disc loss=1.0072128772735596, {hms_string(epoch_elapsed)}
# Epoch 62, gen loss=0.6927725076675415,disc loss=1.006921648979187, {hms_string(epoch_elapsed)}
# Epoch 63, gen loss=0.6927212476730347,disc loss=1.0072294473648071, {hms_string(epoch_elapsed)}
# Epoch 64, gen loss=0.6928371787071228,disc loss=1.0069804191589355, {hms_string(epoch_elapsed)}
# Epoch 65, gen loss=0.6920516490936279,disc loss=1.007964849472046, {hms_string(epoch_elapsed)}
# Epoch 66, gen loss=0.6928293108940125,disc loss=1.0070245265960693, {hms_string(epoch_elapsed)}
# Epoch 67, gen loss=0.6928361654281616,disc loss=1.010182499885559, {hms_string(epoch_elapsed)}
# Epoch 68, gen loss=0.6928746700286865,disc loss=1.0077818632125854, {hms_string(epoch_elapsed)}
# Epoch 69, gen loss=0.6924133896827698,disc loss=1.0072435140609741, {hms_string(epoch_elapsed)}
# Epoch 70, gen loss=0.692694902420044,disc loss=1.0069785118103027, {hms_string(epoch_elapsed)}
# Epoch 71, gen loss=0.69258713722229,disc loss=1.007025957107544, {hms_string(epoch_elapsed)}
# Epoch 72, gen loss=0.6928717494010925,disc loss=1.0067822933197021, {hms_string(epoch_elapsed)}
# Epoch 73, gen loss=0.6926963329315186,disc loss=1.007074236869812, {hms_string(epoch_elapsed)}
# Epoch 74, gen loss=0.6927386522293091,disc loss=1.0068278312683105, {hms_string(epoch_elapsed)}
# Epoch 75, gen loss=0.6926301717758179,disc loss=1.006969928741455, {hms_string(epoch_elapsed)}
# Epoch 76, gen loss=0.6926059722900391,disc loss=1.008967399597168, {hms_string(epoch_elapsed)}
# Epoch 77, gen loss=0.6928725242614746,disc loss=1.006866693496704, {hms_string(epoch_elapsed)}
# Epoch 78, gen loss=0.692710280418396,disc loss=1.0070221424102783, {hms_string(epoch_elapsed)}
# Epoch 79, gen loss=0.6928783655166626,disc loss=1.0068700313568115, {hms_string(epoch_elapsed)}
# Epoch 80, gen loss=0.6926584243774414,disc loss=1.0072351694107056, {hms_string(epoch_elapsed)}
# Epoch 81, gen loss=0.6928203105926514,disc loss=1.006879210472107, {hms_string(epoch_elapsed)}
# Epoch 82, gen loss=0.6926047801971436,disc loss=1.0082554817199707, {hms_string(epoch_elapsed)}
# Epoch 83, gen loss=0.6922721862792969,disc loss=1.0074037313461304, {hms_string(epoch_elapsed)}
# Epoch 84, gen loss=0.6928015947341919,disc loss=1.006793737411499, {hms_string(epoch_elapsed)}
# Epoch 85, gen loss=0.6925230622291565,disc loss=1.0070658922195435, {hms_string(epoch_elapsed)}
# Epoch 86, gen loss=0.6921902894973755,disc loss=1.0074422359466553, {hms_string(epoch_elapsed)}
# Epoch 87, gen loss=0.6926742792129517,disc loss=1.006941318511963, {hms_string(epoch_elapsed)}
# Epoch 88, gen loss=0.6929856538772583,disc loss=1.006672739982605, {hms_string(epoch_elapsed)}
# Epoch 89, gen loss=0.6929988861083984,disc loss=1.0065994262695312, {hms_string(epoch_elapsed)}
# Epoch 90, gen loss=0.6928205490112305,disc loss=1.0067704916000366, {hms_string(epoch_elapsed)}
# Epoch 91, gen loss=0.6929656267166138,disc loss=1.0065981149673462, {hms_string(epoch_elapsed)}
# Epoch 92, gen loss=0.6929609179496765,disc loss=1.0067188739776611, {hms_string(epoch_elapsed)}
# Epoch 93, gen loss=0.6929858326911926,disc loss=1.0066368579864502, {hms_string(epoch_elapsed)}
# Epoch 94, gen loss=0.6923716068267822,disc loss=1.00723397731781, {hms_string(epoch_elapsed)}
# Epoch 95, gen loss=0.6929072141647339,disc loss=1.0066921710968018, {hms_string(epoch_elapsed)}
# Epoch 96, gen loss=0.6927388906478882,disc loss=1.0068745613098145, {hms_string(epoch_elapsed)}
# Epoch 97, gen loss=0.6929446458816528,disc loss=1.0080900192260742, {hms_string(epoch_elapsed)}
# Epoch 98, gen loss=0.6929738521575928,disc loss=1.0066783428192139, {hms_string(epoch_elapsed)}
# Epoch 99, gen loss=0.6926966905593872,disc loss=1.0069429874420166, {hms_string(epoch_elapsed)}
# Epoch 100, gen loss=0.69284588098526,disc loss=1.0078290700912476, {hms_string(epoch_elapsed)}
# Epoch 101, gen loss=0.6924340724945068,disc loss=1.007706880569458, {hms_string(epoch_elapsed)}
# Epoch 102, gen loss=0.6926633715629578,disc loss=1.0069143772125244, {hms_string(epoch_elapsed)}
# Epoch 103, gen loss=0.6928653120994568,disc loss=1.0068180561065674, {hms_string(epoch_elapsed)}
# Epoch 104, gen loss=0.6928247213363647,disc loss=1.006949543952942, {hms_string(epoch_elapsed)}
# Epoch 105, gen loss=0.6930078864097595,disc loss=1.0065791606903076, {hms_string(epoch_elapsed)}
# Epoch 106, gen loss=0.6929978132247925,disc loss=1.0066102743148804, {hms_string(epoch_elapsed)}
# Epoch 107, gen loss=0.6929101347923279,disc loss=1.006885290145874, {hms_string(epoch_elapsed)}
# Epoch 108, gen loss=0.6927297115325928,disc loss=1.006859540939331, {hms_string(epoch_elapsed)}
# Epoch 109, gen loss=0.6923982501029968,disc loss=1.0072530508041382, {hms_string(epoch_elapsed)}
# Epoch 110, gen loss=0.6929962635040283,disc loss=1.0066719055175781, {hms_string(epoch_elapsed)}
# Epoch 111, gen loss=0.6929666996002197,disc loss=1.0068632364273071, {hms_string(epoch_elapsed)}
# Epoch 112, gen loss=0.6926388740539551,disc loss=1.0070856809616089, {hms_string(epoch_elapsed)}
# Epoch 113, gen loss=0.6929367184638977,disc loss=1.0068206787109375, {hms_string(epoch_elapsed)}
# Epoch 114, gen loss=0.6927014589309692,disc loss=1.0069400072097778, {hms_string(epoch_elapsed)}
# Epoch 115, gen loss=0.6928071975708008,disc loss=1.0067888498306274, {hms_string(epoch_elapsed)}
# Epoch 116, gen loss=0.693028450012207,disc loss=1.0081665515899658, {hms_string(epoch_elapsed)}
# Epoch 117, gen loss=0.6928905248641968,disc loss=1.006760835647583, {hms_string(epoch_elapsed)}
# Epoch 118, gen loss=0.6928519606590271,disc loss=1.0070781707763672, {hms_string(epoch_elapsed)}
# Epoch 119, gen loss=0.6927325129508972,disc loss=1.0068778991699219, {hms_string(epoch_elapsed)}
# Epoch 120, gen loss=0.6926984190940857,disc loss=1.0070240497589111, {hms_string(epoch_elapsed)}
# Epoch 121, gen loss=0.6929080486297607,disc loss=1.0067657232284546, {hms_string(epoch_elapsed)}
# Epoch 122, gen loss=0.692896842956543,disc loss=1.0068000555038452, {hms_string(epoch_elapsed)}
# Epoch 123, gen loss=0.6929941177368164,disc loss=1.006691575050354, {hms_string(epoch_elapsed)}
# Epoch 124, gen loss=0.6929301619529724,disc loss=1.0068360567092896, {hms_string(epoch_elapsed)}
# Epoch 125, gen loss=0.6929271221160889,disc loss=1.0068141222000122, {hms_string(epoch_elapsed)}
# Epoch 126, gen loss=0.693023681640625,disc loss=1.006589651107788, {hms_string(epoch_elapsed)}
# Epoch 127, gen loss=0.6928348541259766,disc loss=1.0068501234054565, {hms_string(epoch_elapsed)}
# Epoch 128, gen loss=0.6930279731750488,disc loss=1.0065382719039917, {hms_string(epoch_elapsed)}
# Epoch 129, gen loss=0.6927882432937622,disc loss=1.0069388151168823, {hms_string(epoch_elapsed)}
# Epoch 130, gen loss=0.6928901672363281,disc loss=1.0068925619125366, {hms_string(epoch_elapsed)}
# Epoch 131, gen loss=0.6929543018341064,disc loss=1.0066816806793213, {hms_string(epoch_elapsed)}
# Epoch 132, gen loss=0.6928911209106445,disc loss=1.0067304372787476, {hms_string(epoch_elapsed)}
# Epoch 133, gen loss=0.692976713180542,disc loss=1.0066092014312744, {hms_string(epoch_elapsed)}
# Epoch 134, gen loss=0.6928303837776184,disc loss=1.0067542791366577, {hms_string(epoch_elapsed)}
# Epoch 135, gen loss=0.6928811073303223,disc loss=1.006825566291809, {hms_string(epoch_elapsed)}
# Epoch 136, gen loss=0.6930023431777954,disc loss=1.0066221952438354, {hms_string(epoch_elapsed)}
# Epoch 137, gen loss=0.6930122375488281,disc loss=1.0072152614593506, {hms_string(epoch_elapsed)}
# Epoch 138, gen loss=0.6930213570594788,disc loss=1.0065996646881104, {hms_string(epoch_elapsed)}
# Epoch 139, gen loss=0.6929442882537842,disc loss=1.006758451461792, {hms_string(epoch_elapsed)}
# Epoch 140, gen loss=0.6930501461029053,disc loss=1.0065762996673584, {hms_string(epoch_elapsed)}
# Epoch 141, gen loss=0.6928430795669556,disc loss=1.0068777799606323, {hms_string(epoch_elapsed)}
# Epoch 142, gen loss=0.6929203867912292,disc loss=1.0080833435058594, {hms_string(epoch_elapsed)}
# Epoch 143, gen loss=0.693039059638977,disc loss=1.0067617893218994, {hms_string(epoch_elapsed)}
# Epoch 144, gen loss=0.6930067539215088,disc loss=1.006561517715454, {hms_string(epoch_elapsed)}
# Epoch 145, gen loss=0.6929581165313721,disc loss=1.0067291259765625, {hms_string(epoch_elapsed)}
# Epoch 146, gen loss=0.6927870512008667,disc loss=1.0067800283432007, {hms_string(epoch_elapsed)}
# Epoch 147, gen loss=0.6927291750907898,disc loss=1.0068325996398926, {hms_string(epoch_elapsed)}
# Epoch 148, gen loss=0.6929608583450317,disc loss=1.0066521167755127, {hms_string(epoch_elapsed)}
# Epoch 149, gen loss=0.6929528713226318,disc loss=1.006641149520874, {hms_string(epoch_elapsed)}
# Epoch 150, gen loss=0.6927895545959473,disc loss=1.0068650245666504, {hms_string(epoch_elapsed)}
# Epoch 151, gen loss=0.6927734613418579,disc loss=1.0068187713623047, {hms_string(epoch_elapsed)}
# Epoch 152, gen loss=0.692984938621521,disc loss=1.00681734085083, {hms_string(epoch_elapsed)}
# Epoch 153, gen loss=0.6930762529373169,disc loss=1.0065553188323975, {hms_string(epoch_elapsed)}
# Epoch 154, gen loss=0.6930115222930908,disc loss=1.0066629648208618, {hms_string(epoch_elapsed)}
# Epoch 155, gen loss=0.69303959608078,disc loss=1.0065457820892334, {hms_string(epoch_elapsed)}
# Epoch 156, gen loss=0.6929807662963867,disc loss=1.0067487955093384, {hms_string(epoch_elapsed)}
# Epoch 157, gen loss=0.6930221319198608,disc loss=1.006556510925293, {hms_string(epoch_elapsed)}
# Epoch 158, gen loss=0.692898154258728,disc loss=1.0066947937011719, {hms_string(epoch_elapsed)}
# Epoch 159, gen loss=0.6929816603660583,disc loss=1.006839632987976, {hms_string(epoch_elapsed)}
# Epoch 160, gen loss=0.6929532289505005,disc loss=1.0068897008895874, {hms_string(epoch_elapsed)}
# Epoch 161, gen loss=0.6930195689201355,disc loss=1.0065641403198242, {hms_string(epoch_elapsed)}
# Epoch 162, gen loss=0.6929704546928406,disc loss=1.0066900253295898, {hms_string(epoch_elapsed)}
# Epoch 163, gen loss=0.6929776072502136,disc loss=1.0067999362945557, {hms_string(epoch_elapsed)}
# Epoch 164, gen loss=0.6929296255111694,disc loss=1.0068814754486084, {hms_string(epoch_elapsed)}
# Epoch 165, gen loss=0.6930322647094727,disc loss=1.00654935836792, {hms_string(epoch_elapsed)}
# Epoch 166, gen loss=0.6929030418395996,disc loss=1.0066742897033691, {hms_string(epoch_elapsed)}
# Epoch 167, gen loss=0.6930451989173889,disc loss=1.0067143440246582, {hms_string(epoch_elapsed)}
# Epoch 168, gen loss=0.6929214000701904,disc loss=1.006648302078247, {hms_string(epoch_elapsed)}
# Epoch 169, gen loss=0.6930185556411743,disc loss=1.0065666437149048, {hms_string(epoch_elapsed)}
# Epoch 170, gen loss=0.6929347515106201,disc loss=1.006719946861267, {hms_string(epoch_elapsed)}
# Epoch 171, gen loss=0.692995548248291,disc loss=1.0066031217575073, {hms_string(epoch_elapsed)}
# Epoch 172, gen loss=0.6929833889007568,disc loss=1.0067272186279297, {hms_string(epoch_elapsed)}
# Epoch 173, gen loss=0.693044900894165,disc loss=1.006561279296875, {hms_string(epoch_elapsed)}
# Epoch 174, gen loss=0.6928509473800659,disc loss=1.0067987442016602, {hms_string(epoch_elapsed)}
# Epoch 175, gen loss=0.6929327845573425,disc loss=1.0075206756591797, {hms_string(epoch_elapsed)}
# Epoch 176, gen loss=0.6929926872253418,disc loss=1.0066384077072144, {hms_string(epoch_elapsed)}
# Epoch 177, gen loss=0.6929949522018433,disc loss=1.0065709352493286, {hms_string(epoch_elapsed)}
# Epoch 178, gen loss=0.6928393840789795,disc loss=1.006779670715332, {hms_string(epoch_elapsed)}
# Epoch 179, gen loss=0.6928436756134033,disc loss=1.0072507858276367, {hms_string(epoch_elapsed)}
# Epoch 180, gen loss=0.6929914951324463,disc loss=1.00691819190979, {hms_string(epoch_elapsed)}
# Epoch 181, gen loss=0.6929976940155029,disc loss=1.0066407918930054, {hms_string(epoch_elapsed)}
# Epoch 182, gen loss=0.6929553747177124,disc loss=1.0067851543426514, {hms_string(epoch_elapsed)}
# Epoch 183, gen loss=0.6929588317871094,disc loss=1.0067683458328247, {hms_string(epoch_elapsed)}
# Epoch 184, gen loss=0.6930171251296997,disc loss=1.006563663482666, {hms_string(epoch_elapsed)}
# Epoch 185, gen loss=0.69297194480896,disc loss=1.006743311882019, {hms_string(epoch_elapsed)}
# Epoch 186, gen loss=0.6929671764373779,disc loss=1.0067977905273438, {hms_string(epoch_elapsed)}
# Epoch 187, gen loss=0.6929826140403748,disc loss=1.0066359043121338, {hms_string(epoch_elapsed)}
# Epoch 188, gen loss=0.6929025650024414,disc loss=1.0066566467285156, {hms_string(epoch_elapsed)}
# Epoch 189, gen loss=0.6929892301559448,disc loss=1.0065737962722778, {hms_string(epoch_elapsed)}
# Epoch 190, gen loss=0.6929968595504761,disc loss=1.0066787004470825, {hms_string(epoch_elapsed)}
# Epoch 191, gen loss=0.6930215358734131,disc loss=1.006636142730713, {hms_string(epoch_elapsed)}
# Epoch 192, gen loss=0.6930317878723145,disc loss=1.0066262483596802, {hms_string(epoch_elapsed)}
# Epoch 193, gen loss=0.6925139427185059,disc loss=1.0071547031402588, {hms_string(epoch_elapsed)}
# Epoch 194, gen loss=0.6930500268936157,disc loss=1.0065189599990845, {hms_string(epoch_elapsed)}
# Epoch 195, gen loss=0.6929812431335449,disc loss=1.0066022872924805, {hms_string(epoch_elapsed)}
# Epoch 196, gen loss=0.6929784417152405,disc loss=1.0066115856170654, {hms_string(epoch_elapsed)}
# Epoch 197, gen loss=0.6929595470428467,disc loss=1.0066931247711182, {hms_string(epoch_elapsed)}
# Epoch 198, gen loss=0.692953884601593,disc loss=1.0075654983520508, {hms_string(epoch_elapsed)}
# Epoch 199, gen loss=0.6930322647094727,disc loss=1.0065886974334717, {hms_string(epoch_elapsed)}
# Epoch 200, gen loss=0.6930533051490784,disc loss=1.0066251754760742, {hms_string(epoch_elapsed)}
# Epoch 201, gen loss=0.6930422782897949,disc loss=1.0065621137619019, {hms_string(epoch_elapsed)}
# Epoch 202, gen loss=0.6930227279663086,disc loss=1.0065817832946777, {hms_string(epoch_elapsed)}
# Epoch 203, gen loss=0.6929370164871216,disc loss=1.0067121982574463, {hms_string(epoch_elapsed)}
# Epoch 204, gen loss=0.6928861737251282,disc loss=1.006711721420288, {hms_string(epoch_elapsed)}
# Epoch 205, gen loss=0.6929136514663696,disc loss=1.0067427158355713, {hms_string(epoch_elapsed)}
# Epoch 206, gen loss=0.6925990581512451,disc loss=1.0070810317993164, {hms_string(epoch_elapsed)}
# Epoch 207, gen loss=0.6930297613143921,disc loss=1.0065720081329346, {hms_string(epoch_elapsed)}
# Epoch 208, gen loss=0.6930488348007202,disc loss=1.0065820217132568, {hms_string(epoch_elapsed)}
# Epoch 209, gen loss=0.6927953362464905,disc loss=1.0067745447158813, {hms_string(epoch_elapsed)}
# Epoch 210, gen loss=0.693057656288147,disc loss=1.006882667541504, {hms_string(epoch_elapsed)}
# Epoch 211, gen loss=0.6930935382843018,disc loss=1.0064923763275146, {hms_string(epoch_elapsed)}
# Epoch 212, gen loss=0.6930619478225708,disc loss=1.0067805051803589, {hms_string(epoch_elapsed)}
# Epoch 213, gen loss=0.6930943727493286,disc loss=1.0064778327941895, {hms_string(epoch_elapsed)}
# Epoch 214, gen loss=0.6930974721908569,disc loss=1.0065231323242188, {hms_string(epoch_elapsed)}
# Epoch 215, gen loss=0.6930697560310364,disc loss=1.0066077709197998, {hms_string(epoch_elapsed)}
# Epoch 216, gen loss=0.6930112838745117,disc loss=1.0065958499908447, {hms_string(epoch_elapsed)}
# Epoch 217, gen loss=0.6928478479385376,disc loss=1.0067170858383179, {hms_string(epoch_elapsed)}
# Epoch 218, gen loss=0.6930762529373169,disc loss=1.008048415184021, {hms_string(epoch_elapsed)}
# Epoch 219, gen loss=0.6930482983589172,disc loss=1.006596565246582, {hms_string(epoch_elapsed)}
# Epoch 220, gen loss=0.6930330991744995,disc loss=1.006541132926941, {hms_string(epoch_elapsed)}
# Epoch 221, gen loss=0.6927940249443054,disc loss=1.0068038702011108, {hms_string(epoch_elapsed)}
# Epoch 222, gen loss=0.6930242776870728,disc loss=1.006543755531311, {hms_string(epoch_elapsed)}
# Epoch 223, gen loss=0.6930047273635864,disc loss=1.0065710544586182, {hms_string(epoch_elapsed)}
# Epoch 224, gen loss=0.6930310726165771,disc loss=1.0065501928329468, {hms_string(epoch_elapsed)}
# Epoch 225, gen loss=0.6927700042724609,disc loss=1.0068161487579346, {hms_string(epoch_elapsed)}
# Epoch 226, gen loss=0.6930053234100342,disc loss=1.0065836906433105, {hms_string(epoch_elapsed)}
# Epoch 227, gen loss=0.6928462982177734,disc loss=1.0067541599273682, {hms_string(epoch_elapsed)}
# Epoch 228, gen loss=0.6930623054504395,disc loss=1.0065147876739502, {hms_string(epoch_elapsed)}
# Epoch 229, gen loss=0.6930578947067261,disc loss=1.0065057277679443, {hms_string(epoch_elapsed)}
# Epoch 230, gen loss=0.6929978132247925,disc loss=1.0067229270935059, {hms_string(epoch_elapsed)}
# Epoch 231, gen loss=0.693005383014679,disc loss=1.0066405534744263, {hms_string(epoch_elapsed)}
# Epoch 232, gen loss=0.6929479837417603,disc loss=1.0066449642181396, {hms_string(epoch_elapsed)}
# Epoch 233, gen loss=0.692962646484375,disc loss=1.0067243576049805, {hms_string(epoch_elapsed)}
# Epoch 234, gen loss=0.6930546760559082,disc loss=1.0065337419509888, {hms_string(epoch_elapsed)}
# Epoch 235, gen loss=0.6930115222930908,disc loss=1.006552815437317, {hms_string(epoch_elapsed)}
# Epoch 236, gen loss=0.6930806040763855,disc loss=1.0064793825149536, {hms_string(epoch_elapsed)}
# Epoch 237, gen loss=0.6930141448974609,disc loss=1.0065968036651611, {hms_string(epoch_elapsed)}
# Epoch 238, gen loss=0.6929736137390137,disc loss=1.0066421031951904, {hms_string(epoch_elapsed)}
# Epoch 239, gen loss=0.6930676698684692,disc loss=1.006822109222412, {hms_string(epoch_elapsed)}
# Epoch 240, gen loss=0.6930570602416992,disc loss=1.0065746307373047, {hms_string(epoch_elapsed)}
# Epoch 241, gen loss=0.6930662393569946,disc loss=1.00652277469635, {hms_string(epoch_elapsed)}
# Epoch 242, gen loss=0.6930891275405884,disc loss=1.0065135955810547, {hms_string(epoch_elapsed)}
# Epoch 243, gen loss=0.6930729150772095,disc loss=1.0065903663635254, {hms_string(epoch_elapsed)}
# Epoch 244, gen loss=0.6930701732635498,disc loss=1.0067137479782104, {hms_string(epoch_elapsed)}
# Epoch 245, gen loss=0.6930710077285767,disc loss=1.006505012512207, {hms_string(epoch_elapsed)}
# Epoch 246, gen loss=0.6930563449859619,disc loss=1.0066249370574951, {hms_string(epoch_elapsed)}
# Epoch 247, gen loss=0.6929407715797424,disc loss=1.0066205263137817, {hms_string(epoch_elapsed)}
# Epoch 248, gen loss=0.6931073665618896,disc loss=1.0065484046936035, {hms_string(epoch_elapsed)}
# Epoch 249, gen loss=0.6929904818534851,disc loss=1.006584644317627, {hms_string(epoch_elapsed)}
# Epoch 250, gen loss=0.6930558681488037,disc loss=1.0065122842788696, {hms_string(epoch_elapsed)}
# Epoch 251, gen loss=0.6930120587348938,disc loss=1.0065691471099854, {hms_string(epoch_elapsed)}
# Epoch 252, gen loss=0.6927270889282227,disc loss=1.0068747997283936, {hms_string(epoch_elapsed)}
# Epoch 253, gen loss=0.693081259727478,disc loss=1.0065128803253174, {hms_string(epoch_elapsed)}
# Epoch 254, gen loss=0.6930574178695679,disc loss=1.0065077543258667, {hms_string(epoch_elapsed)}
# Epoch 255, gen loss=0.6929985880851746,disc loss=1.0067822933197021, {hms_string(epoch_elapsed)}
# Epoch 256, gen loss=0.693031370639801,disc loss=1.0065373182296753, {hms_string(epoch_elapsed)}
# Epoch 257, gen loss=0.6930356025695801,disc loss=1.0065257549285889, {hms_string(epoch_elapsed)}
# Epoch 258, gen loss=0.6928480863571167,disc loss=1.0067620277404785, {hms_string(epoch_elapsed)}
# Epoch 259, gen loss=0.6930848360061646,disc loss=1.0066367387771606, {hms_string(epoch_elapsed)}
# Epoch 260, gen loss=0.6929692029953003,disc loss=1.0066211223602295, {hms_string(epoch_elapsed)}
# Epoch 261, gen loss=0.6930714249610901,disc loss=1.006603717803955, {hms_string(epoch_elapsed)}
# Epoch 262, gen loss=0.6931068897247314,disc loss=1.0066378116607666, {hms_string(epoch_elapsed)}
# Epoch 263, gen loss=0.6930994391441345,disc loss=1.0064969062805176, {hms_string(epoch_elapsed)}
# Epoch 264, gen loss=0.6931110620498657,disc loss=1.0064945220947266, {hms_string(epoch_elapsed)}
# Epoch 265, gen loss=0.6930943727493286,disc loss=1.0065021514892578, {hms_string(epoch_elapsed)}
# Epoch 266, gen loss=0.6930776834487915,disc loss=1.0065767765045166, {hms_string(epoch_elapsed)}
# Epoch 267, gen loss=0.6929366588592529,disc loss=1.0067057609558105, {hms_string(epoch_elapsed)}
# Epoch 268, gen loss=0.6931118965148926,disc loss=1.0064592361450195, {hms_string(epoch_elapsed)}
# Epoch 269, gen loss=0.6930474638938904,disc loss=1.0065317153930664, {hms_string(epoch_elapsed)}
# Epoch 270, gen loss=0.6930801868438721,disc loss=1.0067052841186523, {hms_string(epoch_elapsed)}
# Epoch 271, gen loss=0.69307541847229,disc loss=1.0065116882324219, {hms_string(epoch_elapsed)}
# Epoch 272, gen loss=0.6930596232414246,disc loss=1.0066927671432495, {hms_string(epoch_elapsed)}
# Epoch 273, gen loss=0.6930837631225586,disc loss=1.006516933441162, {hms_string(epoch_elapsed)}
# Epoch 274, gen loss=0.6930798888206482,disc loss=1.0065007209777832, {hms_string(epoch_elapsed)}
# Epoch 275, gen loss=0.693053126335144,disc loss=1.0065141916275024, {hms_string(epoch_elapsed)}
# Epoch 276, gen loss=0.693088173866272,disc loss=1.0064820051193237, {hms_string(epoch_elapsed)}
# Epoch 277, gen loss=0.6930960416793823,disc loss=1.0069187879562378, {hms_string(epoch_elapsed)}
# Epoch 278, gen loss=0.6930913925170898,disc loss=1.006554365158081, {hms_string(epoch_elapsed)}
# Epoch 279, gen loss=0.6929928064346313,disc loss=1.0066273212432861, {hms_string(epoch_elapsed)}
# Epoch 280, gen loss=0.6930761337280273,disc loss=1.006486177444458, {hms_string(epoch_elapsed)}
# Epoch 281, gen loss=0.6928967237472534,disc loss=1.006738305091858, {hms_string(epoch_elapsed)}
# Epoch 282, gen loss=0.693041205406189,disc loss=1.0065743923187256, {hms_string(epoch_elapsed)}
# Epoch 283, gen loss=0.6930570602416992,disc loss=1.0065134763717651, {hms_string(epoch_elapsed)}
# Epoch 284, gen loss=0.6928993463516235,disc loss=1.0068724155426025, {hms_string(epoch_elapsed)}
# Epoch 285, gen loss=0.692985475063324,disc loss=1.006580114364624, {hms_string(epoch_elapsed)}
# Epoch 286, gen loss=0.6930529475212097,disc loss=1.0067129135131836, {hms_string(epoch_elapsed)}
# Epoch 287, gen loss=0.6929503679275513,disc loss=1.0067119598388672, {hms_string(epoch_elapsed)}
# Epoch 288, gen loss=0.6931009292602539,disc loss=1.0064897537231445, {hms_string(epoch_elapsed)}
# Epoch 289, gen loss=0.6930779218673706,disc loss=1.0064829587936401, {hms_string(epoch_elapsed)}
# Epoch 290, gen loss=0.6930516958236694,disc loss=1.0065265893936157, {hms_string(epoch_elapsed)}
# Epoch 291, gen loss=0.6931201815605164,disc loss=1.0064764022827148, {hms_string(epoch_elapsed)}
# Epoch 292, gen loss=0.6930673122406006,disc loss=1.0065362453460693, {hms_string(epoch_elapsed)}
# Epoch 293, gen loss=0.6930997967720032,disc loss=1.0068423748016357, {hms_string(epoch_elapsed)}
# Epoch 294, gen loss=0.6930339932441711,disc loss=1.006638765335083, {hms_string(epoch_elapsed)}
# Epoch 295, gen loss=0.6930694580078125,disc loss=1.0065382719039917, {hms_string(epoch_elapsed)}
# Epoch 296, gen loss=0.6930765509605408,disc loss=1.0065003633499146, {hms_string(epoch_elapsed)}
# Epoch 297, gen loss=0.6930993795394897,disc loss=1.0065175294876099, {hms_string(epoch_elapsed)}
# Epoch 298, gen loss=0.6930705904960632,disc loss=1.0065128803253174, {hms_string(epoch_elapsed)}
# Epoch 299, gen loss=0.6930924654006958,disc loss=1.006493091583252, {hms_string(epoch_elapsed)}
# Epoch 300, gen loss=0.6931185722351074,disc loss=1.006440281867981, {hms_string(epoch_elapsed)}
# Epoch 301, gen loss=0.6931058764457703,disc loss=1.0066697597503662, {hms_string(epoch_elapsed)}
# Epoch 302, gen loss=0.6930482387542725,disc loss=1.0065128803253174, {hms_string(epoch_elapsed)}
# Epoch 303, gen loss=0.693080723285675,disc loss=1.0065045356750488, {hms_string(epoch_elapsed)}
# Epoch 304, gen loss=0.6930481791496277,disc loss=1.006520390510559, {hms_string(epoch_elapsed)}
# Epoch 305, gen loss=0.6930361986160278,disc loss=1.006560206413269, {hms_string(epoch_elapsed)}
# Epoch 306, gen loss=0.6930586099624634,disc loss=1.006722331047058, {hms_string(epoch_elapsed)}
# Epoch 307, gen loss=0.69310462474823,disc loss=1.0064717531204224, {hms_string(epoch_elapsed)}
# Epoch 308, gen loss=0.693099856376648,disc loss=1.0064663887023926, {hms_string(epoch_elapsed)}
# Epoch 309, gen loss=0.6930558085441589,disc loss=1.0065281391143799, {hms_string(epoch_elapsed)}
# Epoch 310, gen loss=0.6929539442062378,disc loss=1.0066101551055908, {hms_string(epoch_elapsed)}
# Epoch 311, gen loss=0.6930416822433472,disc loss=1.0067448616027832, {hms_string(epoch_elapsed)}
# Epoch 312, gen loss=0.693121075630188,disc loss=1.0064901113510132, {hms_string(epoch_elapsed)}
# Epoch 313, gen loss=0.6930222511291504,disc loss=1.006567358970642, {hms_string(epoch_elapsed)}
# Epoch 314, gen loss=0.6930712461471558,disc loss=1.0064897537231445, {hms_string(epoch_elapsed)}
# Epoch 315, gen loss=0.6931257247924805,disc loss=1.0064445734024048, {hms_string(epoch_elapsed)}
# Epoch 316, gen loss=0.6930922269821167,disc loss=1.0064753293991089, {hms_string(epoch_elapsed)}
# Epoch 317, gen loss=0.6931024789810181,disc loss=1.0064855813980103, {hms_string(epoch_elapsed)}
# Epoch 318, gen loss=0.6930522322654724,disc loss=1.0066214799880981, {hms_string(epoch_elapsed)}
# Epoch 319, gen loss=0.6930816173553467,disc loss=1.0065748691558838, {hms_string(epoch_elapsed)}
# Epoch 320, gen loss=0.6930371522903442,disc loss=1.006624460220337, {hms_string(epoch_elapsed)}
# Epoch 321, gen loss=0.6930949687957764,disc loss=1.006545066833496, {hms_string(epoch_elapsed)}
# Epoch 322, gen loss=0.6931016445159912,disc loss=1.0064592361450195, {hms_string(epoch_elapsed)}
# Epoch 323, gen loss=0.6930680871009827,disc loss=1.0065048933029175, {hms_string(epoch_elapsed)}
# Epoch 324, gen loss=0.6931134462356567,disc loss=1.0065155029296875, {hms_string(epoch_elapsed)}
# Epoch 325, gen loss=0.693085789680481,disc loss=1.006478190422058, {hms_string(epoch_elapsed)}
# Epoch 326, gen loss=0.6929532289505005,disc loss=1.006622314453125, {hms_string(epoch_elapsed)}
# Epoch 327, gen loss=0.6931078433990479,disc loss=1.006497859954834, {hms_string(epoch_elapsed)}
# Epoch 328, gen loss=0.6930493116378784,disc loss=1.0065199136734009, {hms_string(epoch_elapsed)}
# Epoch 329, gen loss=0.6931043863296509,disc loss=1.0064882040023804, {hms_string(epoch_elapsed)}
# Epoch 330, gen loss=0.6930826306343079,disc loss=1.0065492391586304, {hms_string(epoch_elapsed)}
# Epoch 331, gen loss=0.6930593252182007,disc loss=1.0065228939056396, {hms_string(epoch_elapsed)}
# Epoch 332, gen loss=0.6931045055389404,disc loss=1.0065104961395264, {hms_string(epoch_elapsed)}
# Epoch 333, gen loss=0.6930421590805054,disc loss=1.0065860748291016, {hms_string(epoch_elapsed)}
# Epoch 334, gen loss=0.6930506229400635,disc loss=1.006575107574463, {hms_string(epoch_elapsed)}
# Epoch 335, gen loss=0.6930620074272156,disc loss=1.0065418481826782, {hms_string(epoch_elapsed)}
# Epoch 336, gen loss=0.6930979490280151,disc loss=1.0065581798553467, {hms_string(epoch_elapsed)}
# Epoch 337, gen loss=0.6930762529373169,disc loss=1.0064873695373535, {hms_string(epoch_elapsed)}
# Epoch 338, gen loss=0.6930696368217468,disc loss=1.0065480470657349, {hms_string(epoch_elapsed)}
# Epoch 339, gen loss=0.693057656288147,disc loss=1.0065110921859741, {hms_string(epoch_elapsed)}
# Epoch 340, gen loss=0.6929019093513489,disc loss=1.0069094896316528, {hms_string(epoch_elapsed)}
# Epoch 341, gen loss=0.6931201219558716,disc loss=1.006436824798584, {hms_string(epoch_elapsed)}
# Epoch 342, gen loss=0.6930527687072754,disc loss=1.0068883895874023, {hms_string(epoch_elapsed)}
# Epoch 343, gen loss=0.6930781602859497,disc loss=1.0065152645111084, {hms_string(epoch_elapsed)}
# Epoch 344, gen loss=0.6930638551712036,disc loss=1.0065432786941528, {hms_string(epoch_elapsed)}
# Epoch 345, gen loss=0.693081259727478,disc loss=1.0064809322357178, {hms_string(epoch_elapsed)}
# Epoch 346, gen loss=0.6930385231971741,disc loss=1.00654137134552, {hms_string(epoch_elapsed)}
# Epoch 347, gen loss=0.6929785013198853,disc loss=1.0066157579421997, {hms_string(epoch_elapsed)}
# Epoch 348, gen loss=0.6930968165397644,disc loss=1.0065035820007324, {hms_string(epoch_elapsed)}
# Epoch 349, gen loss=0.6931205987930298,disc loss=1.0064418315887451, {hms_string(epoch_elapsed)}
# Epoch 350, gen loss=0.693079948425293,disc loss=1.0065407752990723, {hms_string(epoch_elapsed)}
# Epoch 351, gen loss=0.6930460929870605,disc loss=1.0065175294876099, {hms_string(epoch_elapsed)}
# Epoch 352, gen loss=0.6930757164955139,disc loss=1.0065288543701172, {hms_string(epoch_elapsed)}
# Epoch 353, gen loss=0.6930349469184875,disc loss=1.006561517715454, {hms_string(epoch_elapsed)}
# Epoch 354, gen loss=0.693068265914917,disc loss=1.006502628326416, {hms_string(epoch_elapsed)}
# Epoch 355, gen loss=0.6931118369102478,disc loss=1.006488561630249, {hms_string(epoch_elapsed)}
# Epoch 356, gen loss=0.6930969953536987,disc loss=1.006470799446106, {hms_string(epoch_elapsed)}
# Epoch 357, gen loss=0.693082332611084,disc loss=1.006483554840088, {hms_string(epoch_elapsed)}
# Epoch 358, gen loss=0.6930396556854248,disc loss=1.0066428184509277, {hms_string(epoch_elapsed)}
# Epoch 359, gen loss=0.6928963661193848,disc loss=1.0067248344421387, {hms_string(epoch_elapsed)}
# Epoch 360, gen loss=0.6931003928184509,disc loss=1.0064592361450195, {hms_string(epoch_elapsed)}
# Epoch 361, gen loss=0.6931149959564209,disc loss=1.0064599514007568, {hms_string(epoch_elapsed)}
# Epoch 362, gen loss=0.692962646484375,disc loss=1.0066030025482178, {hms_string(epoch_elapsed)}
# Epoch 363, gen loss=0.6930758953094482,disc loss=1.0068289041519165, {hms_string(epoch_elapsed)}
# Epoch 364, gen loss=0.6930996179580688,disc loss=1.006460428237915, {hms_string(epoch_elapsed)}
# Epoch 365, gen loss=0.6931023597717285,disc loss=1.0066157579421997, {hms_string(epoch_elapsed)}
# Epoch 366, gen loss=0.6931183934211731,disc loss=1.0064659118652344, {hms_string(epoch_elapsed)}
# Epoch 367, gen loss=0.6930719614028931,disc loss=1.0065515041351318, {hms_string(epoch_elapsed)}
# Epoch 368, gen loss=0.6930972337722778,disc loss=1.006532073020935, {hms_string(epoch_elapsed)}
# Epoch 369, gen loss=0.6931025981903076,disc loss=1.0064773559570312, {hms_string(epoch_elapsed)}
# Epoch 370, gen loss=0.6930922269821167,disc loss=1.0068037509918213, {hms_string(epoch_elapsed)}
# Epoch 371, gen loss=0.6930664777755737,disc loss=1.0065299272537231, {hms_string(epoch_elapsed)}
# Epoch 372, gen loss=0.6930725574493408,disc loss=1.0064938068389893, {hms_string(epoch_elapsed)}
# Epoch 373, gen loss=0.693047285079956,disc loss=1.0065258741378784, {hms_string(epoch_elapsed)}
# Epoch 374, gen loss=0.6931132078170776,disc loss=1.0064632892608643, {hms_string(epoch_elapsed)}
# Epoch 375, gen loss=0.6931217908859253,disc loss=1.00644850730896, {hms_string(epoch_elapsed)}
# Epoch 376, gen loss=0.6930928230285645,disc loss=1.0064787864685059, {hms_string(epoch_elapsed)}
# Epoch 377, gen loss=0.6928088665008545,disc loss=1.006769061088562, {hms_string(epoch_elapsed)}
# Epoch 378, gen loss=0.6930942535400391,disc loss=1.0064724683761597, {hms_string(epoch_elapsed)}
# Epoch 379, gen loss=0.6931009292602539,disc loss=1.0066583156585693, {hms_string(epoch_elapsed)}
# Epoch 380, gen loss=0.6930345892906189,disc loss=1.0065898895263672, {hms_string(epoch_elapsed)}
# Epoch 381, gen loss=0.6930807828903198,disc loss=1.0065091848373413, {hms_string(epoch_elapsed)}
# Epoch 382, gen loss=0.6931119561195374,disc loss=1.0064516067504883, {hms_string(epoch_elapsed)}
# Epoch 383, gen loss=0.6930872201919556,disc loss=1.0064821243286133, {hms_string(epoch_elapsed)}
# Epoch 384, gen loss=0.6930927038192749,disc loss=1.0064928531646729, {hms_string(epoch_elapsed)}
# Epoch 385, gen loss=0.6930732727050781,disc loss=1.0065195560455322, {hms_string(epoch_elapsed)}
# Epoch 386, gen loss=0.6931211352348328,disc loss=1.0065277814865112, {hms_string(epoch_elapsed)}
# Epoch 387, gen loss=0.6930274963378906,disc loss=1.0066046714782715, {hms_string(epoch_elapsed)}
# Epoch 388, gen loss=0.6930574774742126,disc loss=1.0067052841186523, {hms_string(epoch_elapsed)}
# Epoch 389, gen loss=0.6931101083755493,disc loss=1.006455659866333, {hms_string(epoch_elapsed)}
# Epoch 390, gen loss=0.6930540800094604,disc loss=1.0065258741378784, {hms_string(epoch_elapsed)}
# Epoch 391, gen loss=0.6931154727935791,disc loss=1.0066502094268799, {hms_string(epoch_elapsed)}
# Epoch 392, gen loss=0.6930116415023804,disc loss=1.0065771341323853, {hms_string(epoch_elapsed)}
# Epoch 393, gen loss=0.6930789947509766,disc loss=1.006498098373413, {hms_string(epoch_elapsed)}
# Epoch 394, gen loss=0.6930570602416992,disc loss=1.0065007209777832, {hms_string(epoch_elapsed)}
# Epoch 395, gen loss=0.6931164860725403,disc loss=1.0064576864242554, {hms_string(epoch_elapsed)}
# Epoch 396, gen loss=0.6931018829345703,disc loss=1.0064582824707031, {hms_string(epoch_elapsed)}
# Epoch 397, gen loss=0.6930858492851257,disc loss=1.0064821243286133, {hms_string(epoch_elapsed)}
# Epoch 398, gen loss=0.6930397748947144,disc loss=1.0065903663635254, {hms_string(epoch_elapsed)}
# Epoch 399, gen loss=0.6930912733078003,disc loss=1.0065267086029053, {hms_string(epoch_elapsed)}
# Epoch 400, gen loss=0.6931114196777344,disc loss=1.0064677000045776, {hms_string(epoch_elapsed)}
# Epoch 401, gen loss=0.6929555535316467,disc loss=1.006648063659668, {hms_string(epoch_elapsed)}
# Epoch 402, gen loss=0.6931163668632507,disc loss=1.0064650774002075, {hms_string(epoch_elapsed)}
# Epoch 403, gen loss=0.6931279301643372,disc loss=1.006442904472351, {hms_string(epoch_elapsed)}
# Epoch 404, gen loss=0.6930975317955017,disc loss=1.006558895111084, {hms_string(epoch_elapsed)}
# Epoch 405, gen loss=0.6931219696998596,disc loss=1.0064414739608765, {hms_string(epoch_elapsed)}
# Epoch 406, gen loss=0.6930519342422485,disc loss=1.0065178871154785, {hms_string(epoch_elapsed)}
# Epoch 407, gen loss=0.6931183338165283,disc loss=1.006495475769043, {hms_string(epoch_elapsed)}
# Epoch 408, gen loss=0.6931233406066895,disc loss=1.006441593170166, {hms_string(epoch_elapsed)}
# Epoch 409, gen loss=0.6930677890777588,disc loss=1.0065045356750488, {hms_string(epoch_elapsed)}
# Epoch 410, gen loss=0.6931025385856628,disc loss=1.0064754486083984, {hms_string(epoch_elapsed)}
# Epoch 411, gen loss=0.6931267976760864,disc loss=1.0064359903335571, {hms_string(epoch_elapsed)}
# Epoch 412, gen loss=0.693071722984314,disc loss=1.0064878463745117, {hms_string(epoch_elapsed)}
# Epoch 413, gen loss=0.6931145787239075,disc loss=1.0064475536346436, {hms_string(epoch_elapsed)}
# Epoch 414, gen loss=0.6930807828903198,disc loss=1.006493091583252, {hms_string(epoch_elapsed)}
# Epoch 415, gen loss=0.6930989027023315,disc loss=1.0064592361450195, {hms_string(epoch_elapsed)}
# Epoch 416, gen loss=0.6930965185165405,disc loss=1.0064666271209717, {hms_string(epoch_elapsed)}
# Epoch 417, gen loss=0.6931155920028687,disc loss=1.0065646171569824, {hms_string(epoch_elapsed)}
# Epoch 418, gen loss=0.6931139230728149,disc loss=1.0064964294433594, {hms_string(epoch_elapsed)}
# Epoch 419, gen loss=0.6931204795837402,disc loss=1.0064585208892822, {hms_string(epoch_elapsed)}
# Epoch 420, gen loss=0.6931184530258179,disc loss=1.0064631700515747, {hms_string(epoch_elapsed)}
# Epoch 421, gen loss=0.693105936050415,disc loss=1.0066120624542236, {hms_string(epoch_elapsed)}
# Epoch 422, gen loss=0.6930991411209106,disc loss=1.0065175294876099, {hms_string(epoch_elapsed)}
# Epoch 423, gen loss=0.6931194067001343,disc loss=1.0064499378204346, {hms_string(epoch_elapsed)}
# Epoch 424, gen loss=0.69300377368927,disc loss=1.0067321062088013, {hms_string(epoch_elapsed)}
# Epoch 425, gen loss=0.6931079626083374,disc loss=1.0065743923187256, {hms_string(epoch_elapsed)}
# Epoch 426, gen loss=0.6930953860282898,disc loss=1.0064723491668701, {hms_string(epoch_elapsed)}
# Epoch 427, gen loss=0.6931024789810181,disc loss=1.0064928531646729, {hms_string(epoch_elapsed)}
# Epoch 428, gen loss=0.6931204795837402,disc loss=1.006439447402954, {hms_string(epoch_elapsed)}
# Epoch 429, gen loss=0.6931326389312744,disc loss=1.0064442157745361, {hms_string(epoch_elapsed)}
# Epoch 430, gen loss=0.6931037902832031,disc loss=1.0064661502838135, {hms_string(epoch_elapsed)}
# Epoch 431, gen loss=0.6931268572807312,disc loss=1.0064620971679688, {hms_string(epoch_elapsed)}
# Epoch 432, gen loss=0.6930972337722778,disc loss=1.006482481956482, {hms_string(epoch_elapsed)}
# Epoch 433, gen loss=0.6931062936782837,disc loss=1.006465196609497, {hms_string(epoch_elapsed)}
# Epoch 434, gen loss=0.6930912733078003,disc loss=1.0065546035766602, {hms_string(epoch_elapsed)}
# Epoch 435, gen loss=0.6930619478225708,disc loss=1.0065062046051025, {hms_string(epoch_elapsed)}
# Epoch 436, gen loss=0.6931039094924927,disc loss=1.0064789056777954, {hms_string(epoch_elapsed)}
# Epoch 437, gen loss=0.6931201219558716,disc loss=1.0064514875411987, {hms_string(epoch_elapsed)}
# Epoch 438, gen loss=0.6930232048034668,disc loss=1.0065394639968872, {hms_string(epoch_elapsed)}
# Epoch 439, gen loss=0.6930052638053894,disc loss=1.006564974784851, {hms_string(epoch_elapsed)}
# Epoch 440, gen loss=0.6930950880050659,disc loss=1.0064843893051147, {hms_string(epoch_elapsed)}
# Epoch 441, gen loss=0.6931068897247314,disc loss=1.0067999362945557, {hms_string(epoch_elapsed)}
# Epoch 442, gen loss=0.6930969953536987,disc loss=1.006523847579956, {hms_string(epoch_elapsed)}
# Epoch 443, gen loss=0.6930843591690063,disc loss=1.0065010786056519, {hms_string(epoch_elapsed)}
# Epoch 444, gen loss=0.693071722984314,disc loss=1.0065147876739502, {hms_string(epoch_elapsed)}
# Epoch 445, gen loss=0.6930968165397644,disc loss=1.006467342376709, {hms_string(epoch_elapsed)}
# Epoch 446, gen loss=0.693095862865448,disc loss=1.0064693689346313, {hms_string(epoch_elapsed)}
# Epoch 447, gen loss=0.693123996257782,disc loss=1.0064778327941895, {hms_string(epoch_elapsed)}
# Epoch 448, gen loss=0.6930739283561707,disc loss=1.0065621137619019, {hms_string(epoch_elapsed)}
# Epoch 449, gen loss=0.6931061148643494,disc loss=1.0064525604248047, {hms_string(epoch_elapsed)}
# Epoch 450, gen loss=0.6931118965148926,disc loss=1.0064669847488403, {hms_string(epoch_elapsed)}
# Epoch 451, gen loss=0.6931027173995972,disc loss=1.0064618587493896, {hms_string(epoch_elapsed)}
# Epoch 452, gen loss=0.6930215358734131,disc loss=1.0065438747406006, {hms_string(epoch_elapsed)}
# Epoch 453, gen loss=0.6931074857711792,disc loss=1.0064579248428345, {hms_string(epoch_elapsed)}
# Epoch 454, gen loss=0.693130612373352,disc loss=1.0064527988433838, {hms_string(epoch_elapsed)}
# Epoch 455, gen loss=0.6931133270263672,disc loss=1.006527066230774, {hms_string(epoch_elapsed)}
# Epoch 456, gen loss=0.692942202091217,disc loss=1.006641149520874, {hms_string(epoch_elapsed)}
# Epoch 457, gen loss=0.6930358409881592,disc loss=1.0065218210220337, {hms_string(epoch_elapsed)}
# Epoch 458, gen loss=0.6930708289146423,disc loss=1.006507396697998, {hms_string(epoch_elapsed)}
# Epoch 459, gen loss=0.6929750442504883,disc loss=1.0065871477127075, {hms_string(epoch_elapsed)}
# Epoch 460, gen loss=0.6930336952209473,disc loss=1.0065253973007202, {hms_string(epoch_elapsed)}
# Epoch 461, gen loss=0.6931217908859253,disc loss=1.0064390897750854, {hms_string(epoch_elapsed)}
# Epoch 462, gen loss=0.6930988430976868,disc loss=1.0064616203308105, {hms_string(epoch_elapsed)}
# Epoch 463, gen loss=0.693129301071167,disc loss=1.0064458847045898, {hms_string(epoch_elapsed)}
# Epoch 464, gen loss=0.6930456757545471,disc loss=1.0065114498138428, {hms_string(epoch_elapsed)}
# Epoch 465, gen loss=0.6931068897247314,disc loss=1.0064659118652344, {hms_string(epoch_elapsed)}
# Epoch 466, gen loss=0.6931065917015076,disc loss=1.0064804553985596, {hms_string(epoch_elapsed)}
# Epoch 467, gen loss=0.6931301355361938,disc loss=1.0064481496810913, {hms_string(epoch_elapsed)}
# Epoch 468, gen loss=0.6931349039077759,disc loss=1.0064668655395508, {hms_string(epoch_elapsed)}
# Epoch 469, gen loss=0.6931121349334717,disc loss=1.0064586400985718, {hms_string(epoch_elapsed)}
# Epoch 470, gen loss=0.6931136846542358,disc loss=1.0064642429351807, {hms_string(epoch_elapsed)}
# Epoch 471, gen loss=0.6931300163269043,disc loss=1.0064892768859863, {hms_string(epoch_elapsed)}
# Epoch 472, gen loss=0.6931256055831909,disc loss=1.0064976215362549, {hms_string(epoch_elapsed)}
# Epoch 473, gen loss=0.693111777305603,disc loss=1.0064517259597778, {hms_string(epoch_elapsed)}
# Epoch 474, gen loss=0.6931015253067017,disc loss=1.0064899921417236, {hms_string(epoch_elapsed)}
# Epoch 475, gen loss=0.6931268572807312,disc loss=1.0066224336624146, {hms_string(epoch_elapsed)}
# Epoch 476, gen loss=0.6931143999099731,disc loss=1.0065644979476929, {hms_string(epoch_elapsed)}
# Epoch 477, gen loss=0.6931060552597046,disc loss=1.0065479278564453, {hms_string(epoch_elapsed)}
# Epoch 478, gen loss=0.6931253671646118,disc loss=1.0064334869384766, {hms_string(epoch_elapsed)}
# Epoch 479, gen loss=0.6930130124092102,disc loss=1.006556749343872, {hms_string(epoch_elapsed)}
# Epoch 480, gen loss=0.6930810213088989,disc loss=1.0064826011657715, {hms_string(epoch_elapsed)}
# Epoch 481, gen loss=0.6931158304214478,disc loss=1.0064462423324585, {hms_string(epoch_elapsed)}
# Epoch 482, gen loss=0.6931222677230835,disc loss=1.0064420700073242, {hms_string(epoch_elapsed)}
# Epoch 483, gen loss=0.6931278705596924,disc loss=1.0064504146575928, {hms_string(epoch_elapsed)}
# Epoch 484, gen loss=0.6931204199790955,disc loss=1.0064513683319092, {hms_string(epoch_elapsed)}
# Epoch 485, gen loss=0.6931058168411255,disc loss=1.0064823627471924, {hms_string(epoch_elapsed)}
# Epoch 486, gen loss=0.693101167678833,disc loss=1.0064826011657715, {hms_string(epoch_elapsed)}
# Epoch 487, gen loss=0.6931304931640625,disc loss=1.00642991065979, {hms_string(epoch_elapsed)}
# Epoch 488, gen loss=0.6931042671203613,disc loss=1.0064868927001953, {hms_string(epoch_elapsed)}
# Epoch 489, gen loss=0.6931310892105103,disc loss=1.006472110748291, {hms_string(epoch_elapsed)}
# Epoch 490, gen loss=0.6931178569793701,disc loss=1.0064406394958496, {hms_string(epoch_elapsed)}
# Epoch 491, gen loss=0.6930952072143555,disc loss=1.0065722465515137, {hms_string(epoch_elapsed)}
# Epoch 492, gen loss=0.6930698752403259,disc loss=1.0065282583236694, {hms_string(epoch_elapsed)}
# Epoch 493, gen loss=0.69312584400177,disc loss=1.0064406394958496, {hms_string(epoch_elapsed)}
# Epoch 494, gen loss=0.6931319236755371,disc loss=1.0064289569854736, {hms_string(epoch_elapsed)}
# Epoch 495, gen loss=0.6931216716766357,disc loss=1.0065174102783203, {hms_string(epoch_elapsed)}
# Epoch 496, gen loss=0.6930838823318481,disc loss=1.0064899921417236, {hms_string(epoch_elapsed)}
# Epoch 497, gen loss=0.6931223273277283,disc loss=1.0064617395401, {hms_string(epoch_elapsed)}
# Epoch 498, gen loss=0.6931241750717163,disc loss=1.0065933465957642, {hms_string(epoch_elapsed)}
# Epoch 499, gen loss=0.6931189894676208,disc loss=1.0065346956253052, {hms_string(epoch_elapsed)}
# Epoch 500, gen loss=0.6931261420249939,disc loss=1.0064594745635986, {hms_string(epoch_elapsed)}
# Training time: 0:34:29.00

# %%
generator.save(os.path.join(DATA_PATH,"face_generator.h5"))
