# %%
import requests as re
import os

# %%
key = os.environ.get("VISUAL_CROSSING_API_KEY")
aggregateHours="24" 
location = "45.6387,-122.6615"
url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/forecast?location="+location+"&aggregateHours="+aggregateHours+"&key="+key
res = re.get(url)

# %%
print(res)
# Out:
# <Response [200]>

# %%
print(res.text)
# Out:
# Address,Date time,Latitude,Longitude,Resolved Address,Name,Wind Direction,Minimum Temperature,Maximum Temperature,Temperature,Wind Speed,Cloud Cover,Heat Index,Chance Precipitation (%),Precipitation,Sea Level Pressure,Snow Depth,Snow,Relative Humidity,Wind Gust,Wind Chill,Conditions
# "45.6387,-122.6615","07/22/2020",45.6387,-122.6615,"45.6387,-122.6615","45.6387,-122.6615",297.5,62,78,71.6,9.5,21.4,,2,0,1010.8,0,0,57.5,19.5,,"Clear"
# "45.6387,-122.6615","07/23/2020",45.6387,-122.6615,"45.6387,-122.6615","45.6387,-122.6615",294.6,56,74.9,64.1,5.9,51.4,,4,0,1014.4,0,0,66.3,19.5,,"Partially cloudy"
# "45.6387,-122.6615","07/24/2020",45.6387,-122.6615,"45.6387,-122.6615","45.6387,-122.6615",308.8,53,74.9,63,4.9,45.8,,2,0,1015.8,0,0,65.7,17.2,47.8,"Partially cloudy"
# "45.6387,-122.6615","07/25/2020",45.6387,-122.6615,"45.6387,-122.6615","45.6387,-122.6615",331.5,52.1,80,65.1,4.6,27.8,,2,0,1016.3,0,0,61.3,16.1,43.3,"Partially cloudy"
# ...
